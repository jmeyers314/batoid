# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %%
from batoid.app import RubinCSApp

# %%
import ipywidgets
debug = ipywidgets.Output()
# debug

# %%
# Run cell twice to get rid of ipv box
# cyan = x, magenta = y, yellow = z
app = RubinCSApp(maglim=20, debug=debug)
app.display()
